# %%
import requests
from bs4 import BeautifulSoup
import json

# Product page URL
url = "https://pk.sapphireonline.pk/collections/unstitched/products/0U2DEDY25V16"

# Send request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Find the JSON-LD script tag
script_tag = soup.find("script", {"type": "application/ld+json"})

if script_tag:
    # Load JSON data
    product_data = json.loads(script_tag.string)

    # Extract product details
    title = product_data.get("name", "Title Not Found")
    price = product_data.get("offers", {}).get("price", "Price Not Found")
    currency = product_data.get("offers", {}).get("priceCurrency", "Currency Not Found")
    availability = product_data.get("offers", {}).get("availability", "Availability Not Found")
    images = product_data.get("image", [])

    # Print extracted data
    print(f"Title: {title}")
    print(f"Price: {price} {currency}")
    print(f"Availability: {availability}")
    print(f"Images: {images}")
else:
    print("JSON-LD data not found")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\Track Computers\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
# ...

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect("sapphire_products.db")
cursor = conn.cursor()

# Create table
cursor.execute('''CREATE TABLE IF NOT EXISTS products (
                    id INTEGER PRIMARY KEY AUTOINCREMENT,
                    title TEXT,
                    price TEXT,
                    url TEXT,
                    date TIMESTAMP DEFAULT CURRENT_TIMESTAMP
                )''')

conn.commit()
conn.close()

# %%
def save_to_db(products):
    """Saves scraped product details into the database"""
    conn = sqlite3.connect("sapphire_products.db")
    cursor = conn.cursor()

    for product in products:
        cursor.execute("INSERT INTO products (title, price, url) VALUES (?, ?, ?)",
                       (product["title"], product["price"], product["url"]))

    conn.commit()
    conn.close()
    print("✅ Data saved to database!")

# Example usage
save_to_db(data)
# Out:
# ✅ Data saved to database!

# %%
def get_price_history():
    """Retrieve product price history from the database"""
    conn = sqlite3.connect("sapphire_products.db")
    cursor = conn.cursor()

    cursor.execute("SELECT title, price, date FROM products")
    rows = cursor.fetchall()

    conn.close()
    return rows

# Example usage
history = get_price_history()
for record in history:
    print(record)
# Out:
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')

# %%
def get_price_history():
    """Retrieve product price history from the database"""
    conn = sqlite3.connect("sapphire_products.db")
    cursor = conn.cursor()

    cursor.execute("SELECT title, price, date FROM products")
    rows = cursor.fetchall()

    conn.close()
    return rows

# Example usage
history = get_price_history()
for record in history:
    print(record)
# Out:
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')
# ('Title Not Found', 'Price Not Found', '2025-03-17 16:43:33')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_price_trend():
    """Plots price change over time"""
    conn = sqlite3.connect("sapphire_products.db")
    df = pd.read_sql_query("SELECT price, date FROM products", conn)
    conn.close()

    df["date"] = pd.to_datetime(df["date"])
    df["price"] = df["price"].str.replace("PKR", "").str.replace(",", "").astype(float)

    plt.figure(figsize=(10, 5))
    plt.plot(df["date"], df["price"], marker="o", linestyle="-")
    plt.xlabel("Date")
    plt.ylabel("Price (PKR)")
    plt.title("Sapphire Product Price Trend")
    plt.xticks(rotation=45)
    plt.grid()
    plt.show()

# Example usage
plot_price_trend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 23
#      20     plt.show()
#      22 # Example usage
# ---> 23 plot_price_trend()
#
# Cell In[6], line 11, in plot_price_trend()
#       8 conn.close()
#      10 df["date"] = pd.to_datetime(df["date"])
# ---> 11 df["price"] = df["price"].str.replace("PKR", "").str.replace(",", "").astype(float)
#      13 plt.figure(figsize=(10, 5))
#      14 plt.plot(df["date"], df["price"], marker="o", linestyle="-")
#
# File c:\Users\Track Computers\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# ...

# %%
import schedule
import time

def job():
    """Scheduled scraping job"""
    category_url = "https://pk.sapphireonline.pk/collections/unstitched"
    products = get_product_details(category_url)
    save_to_db(products)

# Run daily at 10:00 AM
schedule.every().day.at("10:00").do(job)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
import pandas as pd

def save_to_csv():
    """Save scraped data to a CSV file"""
    conn = sqlite3.connect("sapphire_products.db")
    df = pd.read_sql_query("SELECT * FROM products", conn)
    conn.close()

    df.to_csv("sapphire_product_prices.csv", index=False)
    print("✅ Data saved to sapphire_product_prices.csv!")

# Example usage
save_to_csv()
